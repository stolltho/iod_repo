# %% [markdown]
# # A Complete Pandas Tutorial

# %%
# Source: https://www.kaggle.com/code/rajmehra03/a-complete-pandas-tutorial

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('titanic_train.csv')
df = train.copy()

# %% [markdown]
# ## 1. Basics

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape #attribute
# Out:
# (891, 12)

# %%
# list columns
df.columns #attribute
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# row index
df.index #attribute
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.Pclass.value_counts() #equals
#df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 2. Creating DataFrame

# %%
#empty df
df_empty = pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# from dict to df
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict)
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %%
# from dict to df
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=False)
df_student.head()
# Out:
#    index Name  Age  Roll
# 0      0    A   24     1
# 1      1    B   18     2
# 2      2    C   17     3

# %%
# from dict to df
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=True)
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %% [markdown]
# ## 3. Treating null values

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# on entire df
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# on particular column
df.Age.isnull().sum() #equals
#df['Age'].isnull().sum()
# Out:
# 177

# %%
# Impute null values
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
# Impute
df.Sex.fillna(df.Sex.mode(), inplace=True)
df.Sex.isnull().sum()

#Mode imputation (or mode substitution) replaces missing values of a categorical variable by the mode of non-missing cases of that variable.
# Out:
# 0

# %% [markdown]
# ## 4. Modify/Add new columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex'] = df['Sex'].map({'male':'0','female':'1'})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
a = 'Braund, Mr. Owen Harris'

# %%
a.split(',')[1]
# Out:
# ' Mr. Owen Harris'

# %%
# Finding last name and first name from Name column.
df['last_name'] = df['Name'].apply(lambda x: x.split(',') [0]) 
df['first_name'] = df['Name'].apply(lambda x: ' '.join(x.split(',')[1:])) 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
# Sets to 1 for men in 3rd class
df['ThirdMen'] = df.apply(lambda row: int(row['Pclass']==3 and row['Sex']=='0'), axis=1) # axis=1 > check column

# %%
# Custom function
def findAgeGroup(age):
    if age<18:
        return 1
    elif age>=18 and age<40:
        return 2
    elif age>=40 and age<60:
        return 3
    else:
        return 4
    
df['Age_group'] = df['Age'].apply(lambda x: findAgeGroup(x))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %% [markdown]
# ## 5. Deleting columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %%
df = df.drop(['PassengerId'],axis=1) #axis=0: row, axis=1: column
#df=df.drop(['PassengerId'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass                                               Name Sex  \
# 0         0       3                            Braund, Mr. Owen Harris   0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1
# 2         1       3                             Heikkinen, Miss. Laina   1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1
# 4         0       3                           Allen, Mr. William Henry   0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %% [markdown]
# ## 6. Renaming columns

# %%
# Lets try to rename some columns
df = df.rename(columns={'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %% [markdown]
# ## 7.i Slicing DataFrame

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %%
# All rows with pclass==3
df_third_class = df[df['Pclass']==3].reset_index(drop=True) # reset index
df_third_class.head()
# Out:
#    Survived  Pclass                       Full Name Gender        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.000000      1
# 1         1       3          Heikkinen, Miss. Laina      1  26.000000      0
# 2         0       3        Allen, Mr. William Henry      0  35.000000      0
# 3         0       3                Moran, Mr. James      0  29.699118      0
# 4         0       3  Palsson, Master. Gosta Leonard      0   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 2      0            373450   8.0500   NaN        S      Allen
# 3      0            330877   8.4583   NaN        Q      Moran
# 4      1            349909  21.0750   NaN        S    Palsson
#
#                      Name  ThirdMen  Age_group
# 0         Mr. Owen Harris         1          2
# 1             Miss. Laina         0          2
# 2       Mr. William Henry         1          2
# 3               Mr. James         1          2
# 4   Master. Gosta Leonard         1          1

# %%
# All rows with pclass==3
df_third_class = df[df['Pclass']==3] # index not reset
df_third_class.head()
# Out:
#    Survived  Pclass                       Full Name Gender        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.000000      1
# 2         1       3          Heikkinen, Miss. Laina      1  26.000000      0
# 4         0       3        Allen, Mr. William Henry      0  35.000000      0
# 5         0       3                Moran, Mr. James      0  29.699118      0
# 7         0       3  Palsson, Master. Gosta Leonard      0   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 4      0            373450   8.0500   NaN        S      Allen
# 5      0            330877   8.4583   NaN        Q      Moran
# 7      1            349909  21.0750   NaN        S    Palsson
#
#                      Name  ThirdMen  Age_group
# 0         Mr. Owen Harris         1          2
# 2             Miss. Laina         0          2
# 4       Mr. William Henry         1          2
# 5               Mr. James         1          2
# 7   Master. Gosta Leonard         1          1

# %%
# Females with age > 60
df_aged = df[(df['Age']>60) & (df['Gender']=="1")]
df_aged.head()
# Out:
#      Survived  Pclass                                  Full Name Gender   Age  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia      1  63.0
# 483         1       3                     Turkula, Mrs. (Hedwig)      1  63.0
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)      1  62.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked  Surname  \
# 275      1      0   13502  77.9583    D7        S  Andrews
# 483      0      0    4134   9.5875   NaN        S  Turkula
# 829      0      0  113572  80.0000   B28      NaN    Stone
#
#                                     Name  ThirdMen  Age_group
# 275             Miss. Kornelia Theodosia         0          4
# 483                        Mrs. (Hedwig)         0          4
# 829   Mrs. George Nelson (Martha Evelyn)         0          4

# %%
# Selecting some columns.
df1 = df[['Age','Pclass','Gender']]
df1.head()
# Out:
#     Age  Pclass Gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %%
# Select numerical columns only
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df_num = df.select_dtypes(include=numerics)
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  ThirdMen  Age_group
# 0         0       3  22.0      1      0   7.2500         1          2
# 1         1       1  38.0      1      0  71.2833         0          2
# 2         1       3  26.0      0      0   7.9250         0          2
# 3         1       1  35.0      1      0  53.1000         0          2
# 4         0       3  35.0      0      0   8.0500         1          2

# %%
# categorical columns
df_cat = df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                            Full Name Gender            Ticket  \
# 0                            Braund, Mr. Owen Harris      0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1          PC 17599
# 2                             Heikkinen, Miss. Laina      1  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1            113803
# 4                           Allen, Mr. William Henry      0            373450
#
#   Cabin Embarked    Surname                                         Name
# 0   NaN        S     Braund                              Mr. Owen Harris
# 1   C85        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2   NaN        S  Heikkinen                                  Miss. Laina
# 3  C123        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4   NaN        S      Allen                            Mr. William Henry

# %% [markdown]
# ## 7.ii Slicing using iloc and loc

# %% [markdown]
# **iloc**

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %%
# First 100 rows & all columns
df_sub1 = df.iloc[0:100,:]
df_sub1.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %%
#First 250 rows with a subset of columns

#df_sub2 = df.iloc[:250,['Age']] 
# This will throw an error as iloc only consumes integres as indices.

df_sub2 = df.iloc[:250,[1,8]] 
#Returns first 250 rows and columns at those indices in df.columns.
df_sub2.head()
# Out:
#    Pclass     Fare
# 0       3   7.2500
# 1       1  71.2833
# 2       3   7.9250
# 3       1  53.1000
# 4       3   8.0500

# %% [markdown]
# **loc**

# %%
# First 500 rows.
df_sub3 = df.loc[:500,:]

# %%
# Gender and age of age >50
df_sub4 = df.loc[(df['Age']>50),['Gender','Age']]
df_sub4.head()
# Out:
#    Gender   Age
# 6       0  54.0
# 11      1  58.0
# 15      1  55.0
# 33      0  66.0
# 54      0  65.0

# %% [markdown]
# ## 8. Adding a row

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  ThirdMen  Age_group
# 0                              Mr. Owen Harris         1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)         0          2
# 2                                  Miss. Laina         0          2
# 3           Mrs. Jacques Heath (Lily May Peel)         0          2
# 4                            Mr. William Henry         1          2

# %%
# Adding row using 'append' function
row = dict({'Age':24,'Full Name':'Peter','Survived':'Y'})
df = df.append(row,ignore_index=True)
# assumes NaN for absent keys(columns) !!!

df.tail()
# Out:
# C:\Users\stoll\AppData\Local\Temp\ipykernel_13772\3504008093.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(row,ignore_index=True)
#     Survived  Pclass                                 Full Name Gender  \
# 887        1     1.0              Graham, Miss. Margaret Edith      1
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889        1     1.0                     Behr, Mr. Karl Howell      0
# 890        0     3.0                       Dooley, Mr. Patrick      0
# 891        Y     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 887  19.000000    0.0    0.0      112053  30.00   B42        S    Graham
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                                 Name  ThirdMen  Age_group
# 887             Miss. Margaret Edith       0.0        2.0
# 888   Miss. Catherine Helen "Carrie"       0.0        2.0
# 889                  Mr. Karl Howell       0.0        2.0
# 890                      Mr. Patrick       1.0        2.0
# 891                              NaN       NaN        NaN

# %%
# Adding new row using loc
df.loc[len(df.index)] = row
df.tail()
# Out:
#     Survived  Pclass                                 Full Name Gender  \
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889        1     1.0                     Behr, Mr. Karl Howell      0
# 890        0     3.0                       Dooley, Mr. Patrick      0
# 891        Y     NaN                                     Peter    NaN
# 892        Y     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
# 892  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                                 Name  ThirdMen  Age_group
# 888   Miss. Catherine Helen "Carrie"       0.0        2.0
# 889                  Mr. Karl Howell       0.0        2.0
# 890                      Mr. Patrick       1.0        2.0
# 891                              NaN       NaN        NaN
# 892                              NaN       NaN        NaN

# %% [markdown]
# ## 9. Dropping row(s)

# %%
df = df.drop(df.index[-1], axis=0) # Deletes last row
df.head()
# Out:
#   Survived  Pclass                                          Full Name Gender  \
# 0        0     3.0                            Braund, Mr. Owen Harris      0
# 1        1     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2        1     3.0                             Heikkinen, Miss. Laina      1
# 3        1     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4        0     3.0                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0    1.0    0.0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0    1.0    0.0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0    1.0    0.0            113803  53.1000  C123        S   Futrelle
# 4  35.0    0.0    0.0            373450   8.0500   NaN        S      Allen
#
#                                           Name  ThirdMen  Age_group
# 0                              Mr. Owen Harris       1.0        2.0
# 1   Mrs. John Bradley (Florence Briggs Thayer)       0.0        2.0
# 2                                  Miss. Laina       0.0        2.0
# 3           Mrs. Jacques Heath (Lily May Peel)       0.0        2.0
# 4                            Mr. William Henry       1.0        2.0

# %%
df = df.drop(df.index[:2], axis=0) # Deletes first two rows
df.head()
# Out:
#   Survived  Pclass                                     Full Name Gender  \
# 2        1     3.0                        Heikkinen, Miss. Laina      1
# 3        1     1.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4        0     3.0                      Allen, Mr. William Henry      0
# 5        0     3.0                              Moran, Mr. James      0
# 6        0     1.0                       McCarthy, Mr. Timothy J      0
#
#          Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 2  26.000000    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3  35.000000    1.0    0.0            113803  53.1000  C123        S
# 4  35.000000    0.0    0.0            373450   8.0500   NaN        S
# 5  29.699118    0.0    0.0            330877   8.4583   NaN        Q
# 6  54.000000    0.0    0.0             17463  51.8625   E46        S
#
#      Surname                                 Name  ThirdMen  Age_group
# 2  Heikkinen                          Miss. Laina       0.0        2.0
# 3   Futrelle   Mrs. Jacques Heath (Lily May Peel)       0.0        2.0
# 4      Allen                    Mr. William Henry       1.0        2.0
# 5      Moran                            Mr. James       1.0        2.0
# 6   McCarthy                        Mr. Timothy J       0.0        3.0

# %% [markdown]
# ## 10. Sorting

# %%
df.head()
# Out:
#   Survived  Pclass                                     Full Name Gender  \
# 2        1     3.0                        Heikkinen, Miss. Laina      1
# 3        1     1.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4        0     3.0                      Allen, Mr. William Henry      0
# 5        0     3.0                              Moran, Mr. James      0
# 6        0     1.0                       McCarthy, Mr. Timothy J      0
#
#          Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 2  26.000000    0.0    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3  35.000000    1.0    0.0            113803  53.1000  C123        S
# 4  35.000000    0.0    0.0            373450   8.0500   NaN        S
# 5  29.699118    0.0    0.0            330877   8.4583   NaN        Q
# 6  54.000000    0.0    0.0             17463  51.8625   E46        S
#
#      Surname                                 Name  ThirdMen  Age_group
# 2  Heikkinen                          Miss. Laina       0.0        2.0
# 3   Futrelle   Mrs. Jacques Heath (Lily May Peel)       0.0        2.0
# 4      Allen                    Mr. William Henry       1.0        2.0
# 5      Moran                            Mr. James       1.0        2.0
# 6   McCarthy                        Mr. Timothy J       0.0        3.0

# %%
# sorting by age in decreasing order.
df = df.sort_values(by=['Age'],ascending=False)
df.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  ThirdMen  Age_group
# 630   Mr. Algernon Henry Wilson       0.0        4.0
# 851                   Mr. Johan       1.0        4.0
# 96                 Mr. George B       0.0        4.0
# 493                   Mr. Ramon       0.0        4.0
# 116                 Mr. Patrick       1.0        4.0

# %%
# sorting by age and fare in decreasing order.
list = ['Age', 'Fare']
df = df.sort_values(by=list, ascending=[False, False])
df.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  ThirdMen  Age_group
# 630   Mr. Algernon Henry Wilson       0.0        4.0
# 851                   Mr. Johan       1.0        4.0
# 493                   Mr. Ramon       0.0        4.0
# 96                 Mr. George B       0.0        4.0
# 116                 Mr. Patrick       1.0        4.0

# %% [markdown]
# ## 12. Grouping

# %%
df.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  ThirdMen  Age_group
# 630   Mr. Algernon Henry Wilson       0.0        4.0
# 851                   Mr. Johan       1.0        4.0
# 493                   Mr. Ramon       0.0        4.0
# 96                 Mr. George B       0.0        4.0
# 116                 Mr. Patrick       1.0        4.0

# %%
groups = df.groupby(['Pclass'])
groups.groups
# Out:
# {1.0: [630, 493, 96, 745, 54, 456, 438, 545, 275, 829, 555, 252, 170, 625, 587, 366, 694, 268, 195, 659, 487, 11, 879, 647, 174, 467, 492, 496, 124, 513, 6, 571, 820, 262, 591, 449, 765, 155, 857, 299, 660, 544, 434, 177, 698, 453, 52, 599, 796, 645, 712, 556, 460, 862, 871, 110, 462, 515, 662, 789, 92, 331, 856, 62, 339, 536, 187, 245, 523, 194, 779, 380, 621, 35, 707, 337, 609, 319, 209, 30, 263, 581, 835, 558, 577, 806, 716, 332, 224, 61, 822, 137, 248, 273, 679, 325, 763, 390, 741, 540, ...], 2.0: [672, 33, 570, 684, 232, 626, 772, 15, 249, 582, 774, 317, 695, 714, 150, 259, 723, 458, 526, 754, 463, 586, 397, 440, 706, 236, 854, 314, 217, 432, 865, 149, 288, 272, 670, 161, 346, 705, 808, 795, 357, 594, 148, 450, 518, 387, 344, 327, 292, 265, 20, 211, 812, 416, 99, 98, 476, 405, 576, 722, 800, 21, 516, 472, 506, 239, 122, 123, 665, 543, 190, 70, 817, 801, 637, 673, 439, 308, 726, 178, 418, 213, 747, 322, 219, 596, 181, 547, 17, 303, 481, 732, 277, 466, 413, 674, 361, 53, 133, 117, ...], 3.0: [851, 116, 280, 483, 326, 94, 152, 222, 406, 631, 482, 597, 736, 771, 132, 873, 592, 203, 167, 362, 338, 276, 129, 160, 696, 603, 414, 678, 668, 818, 349, 197, 699, 845, 638, 254, 860, 761, 153, 525, 360, 188, 40, 561, 661, 13, 610, 885, 811, 528, 400, 25, 471, 108, 465, 503, 104, 595, 559, 605, 189, 663, 179, 279, 614, 4, 847, 590, 363, 843, 616, 461, 758, 202, 548, 85, 752, 285, 103, 881, 130, 719, 74, 838, 206, 657, 769, 429, 382, 636, 579, 519, 569, 890, 328, 18, 797, 744, 396, 805, ...]}

# %%
# Show group 1 for Pclass
groups.get_group(1)
# Out:
#     Survived  Pclass                             Full Name Gender    Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.00
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.00
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.00
# 745        0     1.0          Crosby, Capt. Edward Gifford      0  70.00
# 54         0     1.0        Ostby, Mr. Engelhart Cornelius      0  65.00
# ..       ...     ...                                   ...    ...    ...
# 435        1     1.0             Carter, Miss. Lucile Polk      1  14.00
# 802        1     1.0   Carter, Master. William Thornton II      0  11.00
# 445        1     1.0             Dodge, Master. Washington      0   4.00
# 297        0     1.0          Allison, Miss. Helen Loraine      1   2.00
# 305        1     1.0        Allison, Master. Hudson Trevor      0   0.92
#
#      SibSp  Parch     Ticket      Fare    Cabin Embarked       Surname  \
# 630    0.0    0.0      27042   30.0000      A23        S     Barkworth
# 493    0.0    0.0   PC 17609   49.5042      NaN        C  Artagaveytia
# 96     0.0    0.0   PC 17754   34.6542       A5        C   Goldschmidt
# 745    1.0    1.0  WE/P 5735   71.0000      B22        S        Crosby
# 54     0.0    1.0     113509   61.9792      B30        C         Ostby
# ..     ...    ...        ...       ...      ...      ...           ...
# 435    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 802    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 445    0.0    2.0      33638   81.8583      A34        S         Dodge
# 297    1.0    2.0     113781  151.5500  C22 C26        S       Allison
# 305    1.0    2.0     113781  151.5500  C22 C26        S       Allison
#
#                              Name  ThirdMen  Age_group
# 630     Mr. Algernon Henry Wilson       0.0        4.0
# 493                     Mr. Ramon       0.0        4.0
# 96                   Mr. George B       0.0        4.0
# 745          Capt. Edward Gifford       0.0        4.0
# 54        Mr. Engelhart Cornelius       0.0        4.0
# ..                            ...       ...        ...
# 435             Miss. Lucile Polk       0.0        1.0
# 802   Master. William Thornton II       0.0        1.0
# 445            Master. Washington       0.0        1.0
# 297           Miss. Helen Loraine       0.0        1.0
# 305         Master. Hudson Trevor       0.0        1.0
#
# [215 rows x 15 columns]

# %%
# Group by Pclass
df_grp1 = df.groupby(['Pclass'])
df_grp1.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
# 745        0     1.0          Crosby, Capt. Edward Gifford      0  70.0
# 672        0     2.0           Mitchell, Mr. Henry Michael      0  70.0
# 33         0     2.0                 Wheadon, Mr. Edward H      0  66.0
# 54         0     1.0        Ostby, Mr. Engelhart Cornelius      0  65.0
# 280        0     3.0                      Duane, Mr. Frank      0  65.0
# 483        1     3.0                Turkula, Mrs. (Hedwig)      1  63.0
# 570        1     2.0                    Harris, Mr. George      0  62.0
# 326        0     3.0             Nysveen, Mr. Johan Hansen      0  61.0
# 684        0     2.0     Brown, Mr. Thomas William Solomon      0  60.0
# 232        0     2.0             Sjostedt, Mr. Ernst Adolf      0  59.0
#
#      SibSp  Parch       Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0        27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0       347060   7.7750   NaN        S      Svensson
# 493    0.0    0.0     PC 17609  49.5042   NaN        C  Artagaveytia
# 96     0.0    0.0     PC 17754  34.6542    A5        C   Goldschmidt
# 116    0.0    0.0       370369   7.7500   NaN        Q       Connors
# 745    1.0    1.0    WE/P 5735  71.0000   B22        S        Crosby
# 672    0.0    0.0   C.A. 24580  10.5000   NaN        S      Mitchell
# 33     0.0    0.0   C.A. 24579  10.5000   NaN        S       Wheadon
# 54     0.0    1.0       113509  61.9792   B30        C         Ostby
# 280    0.0    0.0       336439   7.7500   NaN        Q         Duane
# 483    0.0    0.0         4134   9.5875   NaN        S       Turkula
# 570    0.0    0.0  S.W./PP 752  10.5000   NaN        S        Harris
# 326    0.0    0.0       345364   6.2375   NaN        S       Nysveen
# 684    1.0    1.0        29750  39.0000   NaN        S         Brown
# 232    0.0    0.0       237442  13.5000   NaN        S      Sjostedt
#
#                             Name  ThirdMen  Age_group
# 630    Mr. Algernon Henry Wilson       0.0        4.0
# 851                    Mr. Johan       1.0        4.0
# 493                    Mr. Ramon       0.0        4.0
# 96                  Mr. George B       0.0        4.0
# 116                  Mr. Patrick       1.0        4.0
# 745         Capt. Edward Gifford       0.0        4.0
# 672            Mr. Henry Michael       0.0        4.0
# 33                  Mr. Edward H       0.0        4.0
# 54       Mr. Engelhart Cornelius       0.0        4.0
# 280                    Mr. Frank       1.0        4.0
# 483                Mrs. (Hedwig)       0.0        4.0
# 570                   Mr. George       0.0        4.0
# 326             Mr. Johan Hansen       1.0        4.0
# 684   Mr. Thomas William Solomon       0.0        4.0
# 232              Mr. Ernst Adolf       0.0        3.0

# %%
# Average Age per Pclass
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    37.043691
# 2.0    29.866958
# 3.0    26.412245
# Name: Age, dtype: float64

# %%
# Alternatively, average Age per Pclass in one line of code
df.groupby(['Pclass']).Age.mean() #equals
#df.groupby(['Pclass'])['Age'].mean()
# Out:
# Pclass
# 1.0    37.043691
# 2.0    29.866958
# 3.0    26.412245
# Name: Age, dtype: float64

# %%
#Average Fare per Pclass
df_grp1['Fare'].mean()
# Out:
# Pclass
# 1.0    84.214554
# 2.0    20.662183
# 3.0    13.688663
# Name: Fare, dtype: float64

# %%
# Alternatively, ave fare for Pclass 1
df[df.Pclass == 1].Fare.mean() #equals
#df[df['Pclass'] == 1].Fare.mean()
#df[df['Pclass'] == 1]['Fare'].mean()
# Out:
# 84.21455441860466

# %%
df.groupby(['Pclass']).Fare.mean()
# Out:
# Pclass
# 1.0    84.214554
# 2.0    20.662183
# 3.0    13.688663
# Name: Fare, dtype: float64

# %%
# Who paid most fare?
print(df.Fare.max())
df[df['Fare'] >512]
# Out:
# 512.3292
#     Survived  Pclass                           Full Name Gender   Age  SibSp  \
# 679        1     1.0  Cardeza, Mr. Thomas Drake Martinez      0  36.0    0.0
# 258        1     1.0                    Ward, Miss. Anna      1  35.0    0.0
# 737        1     1.0              Lesurer, Mr. Gustave J      0  35.0    0.0
#
#      Parch    Ticket      Fare        Cabin Embarked  Surname  \
# 679    1.0  PC 17755  512.3292  B51 B53 B55        C  Cardeza
# 258    0.0  PC 17755  512.3292          NaN        C     Ward
# 737    0.0  PC 17755  512.3292         B101        C  Lesurer
#
#                            Name  ThirdMen  Age_group
# 679   Mr. Thomas Drake Martinez       0.0        2.0
# 258                  Miss. Anna       0.0        2.0
# 737               Mr. Gustave J       0.0        2.0

# %%
# Min/Max age per Pclass
df_grp1['Age'].min()
# Out:
# Pclass
# 1.0    0.92
# 2.0    0.67
# 3.0    0.42
# Name: Age, dtype: float64

# %%
# Count
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    215
# 2.0    184
# 3.0    490
# Name: Age, dtype: int64

# %% [markdown]
# **Using ```agg()``` function**
#
# We can use the aggregate function to aggregate results based on some column or our custom condition

# %%
df = train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df.Survived == 1].Sex.value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df_survived=df[(df['Sex']=='female') & (df['Survived']==1)]
df_survived.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                      Sex     Age   SibSp  Parch  Ticket    Fare      Cabin            Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)       female  38.0  1      0      PC 17599  71.2833   C85              C           1
# 701          1         1       Astor, Mrs. John Jacob (Madeleine Talmadge Force)         female  18.0  1      0      PC 17757  227.5250  C62 C64          C           1
# 642          1         1       Sagesser, Mlle. Emma                                      female  24.0  0      0      PC 17477  69.3000   B35              C           1
# 628          1         1       Longley, Miss. Gretchen Fiske                             female  21.0  0      0      13502     77.9583   D9               S           1
# 619          1         2       Becker, Miss. Marion Louise                               female  4.0   2      1      230136    39.0000   F4               S           1
#                                                                                                                                                                      ..
# 320          1         1       Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)  female  40.0  1      1      16966     134.5000  E34              C           1
# 319          1         1       Wick, Miss. Mary Natalie                                  female  31.0  0      2      36928     164.8667  C7               S           1
# 312          1         1       Ryerson, Miss. Emily Borie                                female  18.0  2      2      PC 17608  262.3750  B57 B59 B63 B66  C           1
# 311          1         1       Hays, Miss. Margaret Bechstein                            female  24.0  0      0      11767     83.1583   C54              C           1
# 888          1         1       Graham, Miss. Margaret Edith                              female  19.0  0      0      112053    30.0000   B42              S           1
# Length: 82, dtype: int64

# %%
# Average per Pclass using 'agg' this time
df_grp2 = df.groupby(['Pclass']).agg({'Age':lambda x: np.mean(x)}) 
df_grp2.head()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
# Min/Max, count, Sum for each Pclass usign agg function
df_grp3 = df.groupby(['Pclass']).agg({'Age':'min'}).rename(columns={'Age':'Min Age'})
# Use 'max'/'sum' etc. for that operation. Note that this ignores 'nan' values.
df_grp3.head()
# Out:
#         Min Age
# Pclass
# 1          0.92
# 2          0.67
# 3          0.42

# %%
# Names of all the pasengers in that class.
df_grp4 = df.groupby(['Pclass']).agg({'Name':lambda x:', '.join(x)})
df_grp4.head()
# Out:
#                                                      Name
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem), Hewlett, ...
# 3       Braund, Mr. Owen Harris, Heikkinen, Miss. Lain...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_grp5 = df.groupby(['Pclass']).agg({'Age':['max','min']})
df_grp5.head() # Creates a MultiOndex Dataframe
# Out:
#          Age
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %% [markdown]
# ## 13. Bonus: Iterating over rows in dataframe

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
for index,row in df.iterrows():
    # do something with row, say:
    print(row)
    pass
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object
# PassengerId                          7
# Survived                             0
# Pclass                               1
# Name           McCarthy, Mr. Timothy J
# Sex                               male
# Age                               54.0
# SibSp                                0
# Parch                                0
# Ticket                           17463
# Fare                           51.8625
# Cabin                              E46
# Embarked                             S
# Name: 6, dtype: object
# PassengerId                                 8
# Survived                                    0
# Pclass                                      3
# Name           Palsson, Master. Gosta Leonard
# Sex                                      male
# Age                                       2.0
# SibSp                                       3
# Parch                                       1
# Ticket                                 349909
# Fare                                   21.075
# Cabin                                     NaN
# Embarked                                    S
# Name: 7, dtype: object
# PassengerId                                                    9
# Survived                                                       1
# Pclass                                                         3
# Name           Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Sex                                                       female
# Age                                                         27.0
# SibSp                                                          0
# Parch                                                          2
# Ticket                                                    347742
# Fare                                                     11.1333
# Cabin                                                        NaN
# Embarked                                                       S
# Name: 8, dtype: object
# PassengerId                                     10
# Survived                                         1
# Pclass                                           2
# Name           Nasser, Mrs. Nicholas (Adele Achem)
# Sex                                         female
# Age                                           14.0
# SibSp                                            1
# Parch                                            0
# Ticket                                      237736
# Fare                                       30.0708
# Cabin                                          NaN
# Embarked                                         C
# Name: 9, dtype: object
# PassengerId                                 11
# Survived                                     1
# Pclass                                       3
# Name           Sandstrom, Miss. Marguerite Rut
# Sex                                     female
# Age                                        4.0
# SibSp                                        1
# Parch                                        1
# Ticket                                 PP 9549
# Fare                                      16.7
# Cabin                                       G6
# Embarked                                     S
# Name: 10, dtype: object
# PassengerId                          12
# Survived                              1
# Pclass                                1
# Name           Bonnell, Miss. Elizabeth
# Sex                              female
# Age                                58.0
# SibSp                                 0
# Parch                                 0
# Ticket                           113783
# Fare                              26.55
# Cabin                              C103
# Embarked                              S
# Name: 11, dtype: object
# PassengerId                                13
# Survived                                    0
# Pclass                                      3
# Name           Saundercock, Mr. William Henry
# Sex                                      male
# Age                                      20.0
# SibSp                                       0
# Parch                                       0
# Ticket                              A/5. 2151
# Fare                                     8.05
# Cabin                                     NaN
# Embarked                                    S
# Name: 12, dtype: object
# PassengerId                             14
# Survived                                 0
# Pclass                                   3
# Name           Andersson, Mr. Anders Johan
# Sex                                   male
# Age                                   39.0
# SibSp                                    1
# Parch                                    5
# Ticket                              347082
# Fare                                31.275
# Cabin                                  NaN
# Embarked                                 S
# Name: 13, dtype: object
# PassengerId                                      15
# Survived                                          0
# Pclass                                            3
# Name           Vestrom, Miss. Hulda Amanda Adolfina
# Sex                                          female
# Age                                            14.0
# SibSp                                             0
# Parch                                             0
# Ticket                                       350406
# Fare                                         7.8542
# Cabin                                           NaN
# Embarked                                          S
# Name: 14, dtype: object
# PassengerId                                  16
# Survived                                      1
# Pclass                                        2
# Name           Hewlett, Mrs. (Mary D Kingcome)
# Sex                                      female
# Age                                        55.0
# SibSp                                         0
# Parch                                         0
# Ticket                                   248706
# Fare                                       16.0
# Cabin                                       NaN
# Embarked                                      S
# Name: 15, dtype: object
# PassengerId                      17
# Survived                          0
# Pclass                            3
# Name           Rice, Master. Eugene
# Sex                            male
# Age                             2.0
# SibSp                             4
# Parch                             1
# Ticket                       382652
# Fare                         29.125
# Cabin                           NaN
# Embarked                          Q
# Name: 16, dtype: object
# PassengerId                              18
# Survived                                  1
# Pclass                                    2
# Name           Williams, Mr. Charles Eugene
# Sex                                    male
# Age                                     NaN
# SibSp                                     0
# Parch                                     0
# Ticket                               244373
# Fare                                   13.0
# Cabin                                   NaN
# Embarked                                  S
# Name: 17, dtype: object
# PassengerId                                                   19
# Survived                                                       0
# Pclass                                                         3
# Name           Vander Planke, Mrs. Julius (Emelia Maria Vande...
# Sex                                                       female
# Age                                                         31.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                    345763
# Fare                                                        18.0
# Cabin                                                        NaN
# Embarked                                                       S
# Name: 18, dtype: object
# PassengerId                         20
# Survived                             1
# Pclass                               3
# Name           Masselmani, Mrs. Fatima
# Sex                             female
# Age                                NaN
# SibSp                                0
# Parch                                0
# Ticket                            2649
# Fare                             7.225
# Cabin                              NaN
# Embarked                             C
# Name: 19, dtype: object
# PassengerId                      21
# Survived                          0
# Pclass                            2
# Name           Fynney, Mr. Joseph J
# Sex                            male
# Age                            35.0
# SibSp                             0
# Parch                             0
# Ticket                       239865
# Fare                           26.0
# Cabin                           NaN
# Embarked                          S
# Name: 20, dtype: object
# PassengerId                       22
# Survived                           1
# Pclass                             2
# Name           Beesley, Mr. Lawrence
# Sex                             male
# Age                             34.0
# SibSp                              0
# Parch                              0
# Ticket                        248698
# Fare                            13.0
# Cabin                            D56
# Embarked                           S
# Name: 21, dtype: object
# PassengerId                             23
# Survived                                 1
# Pclass                                   3
# Name           McGowan, Miss. Anna "Annie"
# Sex                                 female
# Age                                   15.0
# SibSp                                    0
# Parch                                    0
# Ticket                              330923
# Fare                                8.0292
# Cabin                                  NaN
# Embarked                                 Q
# Name: 22, dtype: object
# PassengerId                              24
# Survived                                  1
# Pclass                                    1
# Name           Sloper, Mr. William Thompson
# Sex                                    male
# Age                                    28.0
# SibSp                                     0
# Parch                                     0
# Ticket                               113788
# Fare                                   35.5
# Cabin                                    A6
# Embarked                                  S
# Name: 23, dtype: object
# PassengerId                               25
# Survived                                   0
# Pclass                                     3
# Name           Palsson, Miss. Torborg Danira
# Sex                                   female
# Age                                      8.0
# SibSp                                      3
# Parch                                      1
# Ticket                                349909
# Fare                                  21.075
# Cabin                                    NaN
# Embarked                                   S
# Name: 24, dtype: object
# PassengerId                                                   26
# Survived                                                       1
# Pclass                                                         3
# Name           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          5
# Ticket                                                    347077
# Fare                                                     31.3875
# Cabin                                                        NaN
# Embarked                                                       S
# Name: 25, dtype: object
# PassengerId                         27
# Survived                             0
# Pclass                               3
# Name           Emir, Mr. Farred Chehab
# Sex                               male
# Age                                NaN
# SibSp                                0
# Parch                                0
# Ticket                            2631
# Fare                             7.225
# Cabin                              NaN
# Embarked                             C
# Name: 26, dtype: object
# PassengerId                                28
# Survived                                    0
# Pclass                                      1
# Name           Fortune, Mr. Charles Alexander
# Sex                                      male
# Age                                      19.0
# SibSp                                       3
# Parch                                       2
# Ticket                                  19950
# Fare                                    263.0
# Cabin                             C23 C25 C27
# Embarked                                    S
# Name: 27, dtype: object
# PassengerId                               29
# Survived                                   1
# Pclass                                     3
# Name           O'Dwyer, Miss. Ellen "Nellie"
# Sex                                   female
# Age                                      NaN
# SibSp                                      0
# Parch                                      0
# Ticket                                330959
# Fare                                  7.8792
# Cabin                                    NaN
# Embarked                                   Q
# Name: 28, dtype: object
# PassengerId                     30
# Survived                         0
# Pclass                           3
# Name           Todoroff, Mr. Lalio
# Sex                           male
# Age                            NaN
# SibSp                            0
# Parch                            0
# Ticket                      349216
# Fare                        7.8958
# Cabin                          NaN
# Embarked                         S
# Name: 29, dtype: object
# PassengerId                          31
# Survived                              0
# Pclass                                1
# Name           Uruchurtu, Don. Manuel E
# Sex                                male
# Age                                40.0
# SibSp                                 0
# Parch                                 0
# Ticket                         PC 17601
# Fare                            27.7208
# Cabin                               NaN
# Embarked                              C
# Name: 30, dtype: object
# PassengerId                                                32
# Survived                                                    1
# Pclass                                                      1
# Name           Spencer, Mrs. William Augustus (Marie Eugenie)
# Sex                                                    female
# Age                                                       NaN
# SibSp                                                       1
# Parch                                                       0
# Ticket                                               PC 17569
# Fare                                                 146.5208
# Cabin                                                     B78
# Embarked                                                    C
# Name: 31, dtype: object
# PassengerId                          33
# Survived                              1
# Pclass                                3
# Name           Glynn, Miss. Mary Agatha
# Sex                              female
# Age                                 NaN
# SibSp                                 0
# Parch                                 0
# Ticket                           335677
# Fare                               7.75
# Cabin                               NaN
# Embarked                              Q
# Name: 32, dtype: object
# PassengerId                       34
# Survived                           0
# Pclass                             2
# Name           Wheadon, Mr. Edward H
# Sex                             male
# Age                             66.0
# SibSp                              0
# Parch                              0
# Ticket                    C.A. 24579
# Fare                            10.5
# Cabin                            NaN
# Embarked                           S
# Name: 33, dtype: object
# PassengerId                         35
# Survived                             0
# Pclass                               1
# Name           Meyer, Mr. Edgar Joseph
# Sex                               male
# Age                               28.0
# SibSp                                1
# Parch                                0
# Ticket                        PC 17604
# Fare                           82.1708
# Cabin                              NaN
# Embarked                             C
# Name: 34, dtype: object
# PassengerId                                36
# Survived                                    0
# Pclass                                      1
# Name           Holverson, Mr. Alexander Oskar
# Sex                                      male
# Age                                      42.0
# SibSp                                       1
# Parch                                       0
# Ticket                                 113789
# Fare                                     52.0
# Cabin                                     NaN
# Embarked                                    S
# Name: 35, dtype: object
# PassengerId                  37
# Survived                      1
# Pclass                        3
# Name           Mamee, Mr. Hanna
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                     2677
# Fare                     7.2292
# Cabin                       NaN
# Embarked                      C
# Name: 36, dtype: object
# PassengerId                          38
# Survived                              0
# Pclass                                3
# Name           Cann, Mr. Ernest Charles
# Sex                                male
# Age                                21.0
# SibSp                                 0
# Parch                                 0
# Ticket                       A./5. 2152
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 37, dtype: object
# PassengerId                                    39
# Survived                                        0
# Pclass                                          3
# Name           Vander Planke, Miss. Augusta Maria
# Sex                                        female
# Age                                          18.0
# SibSp                                           2
# Parch                                           0
# Ticket                                     345764
# Fare                                         18.0
# Cabin                                         NaN
# Embarked                                        S
# Name: 38, dtype: object
# PassengerId                             40
# Survived                                 1
# Pclass                                   3
# Name           Nicola-Yarred, Miss. Jamila
# Sex                                 female
# Age                                   14.0
# SibSp                                    1
# Parch                                    0
# Ticket                                2651
# Fare                               11.2417
# Cabin                                  NaN
# Embarked                                 C
# Name: 39, dtype: object
# PassengerId                                                41
# Survived                                                    0
# Pclass                                                      3
# Name           Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Sex                                                    female
# Age                                                      40.0
# SibSp                                                       1
# Parch                                                       0
# Ticket                                                   7546
# Fare                                                    9.475
# Cabin                                                     NaN
# Embarked                                                    S
# Name: 40, dtype: object
# PassengerId                                                   42
# Survived                                                       0
# Pclass                                                         2
# Name           Turpin, Mrs. William John Robert (Dorothy Ann ...
# Sex                                                       female
# Age                                                         27.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                     11668
# Fare                                                        21.0
# Cabin                                                        NaN
# Embarked                                                       S
# Name: 41, dtype: object
# PassengerId                     43
# Survived                         0
# Pclass                           3
# Name           Kraeff, Mr. Theodor
# Sex                           male
# Age                            NaN
# SibSp                            0
# Parch                            0
# Ticket                      349253
# Fare                        7.8958
# Cabin                          NaN
# Embarked                         C
# Name: 42, dtype: object
# PassengerId                                          44
# Survived                                              1
# Pclass                                                2
# Name           Laroche, Miss. Simonne Marie Anne Andree
# Sex                                              female
# Age                                                 3.0
# SibSp                                                 1
# Parch                                                 2
# Ticket                                    SC/Paris 2123
# Fare                                            41.5792
# Cabin                                               NaN
# Embarked                                              C
# Name: 43, dtype: object
# PassengerId                               45
# Survived                                   1
# Pclass                                     3
# Name           Devaney, Miss. Margaret Delia
# Sex                                   female
# Age                                     19.0
# SibSp                                      0
# Parch                                      0
# Ticket                                330958
# Fare                                  7.8792
# Cabin                                    NaN
# Embarked                                   Q
# Name: 44, dtype: object
# PassengerId                          46
# Survived                              0
# Pclass                                3
# Name           Rogers, Mr. William John
# Sex                                male
# Age                                 NaN
# SibSp                                 0
# Parch                                 0
# Ticket                  S.C./A.4. 23567
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 45, dtype: object
# PassengerId                   47
# Survived                       0
# Pclass                         3
# Name           Lennon, Mr. Denis
# Sex                         male
# Age                          NaN
# SibSp                          1
# Parch                          0
# Ticket                    370371
# Fare                        15.5
# Cabin                        NaN
# Embarked                       Q
# Name: 46, dtype: object
# PassengerId                           48
# Survived                               1
# Pclass                                 3
# Name           O'Driscoll, Miss. Bridget
# Sex                               female
# Age                                  NaN
# SibSp                                  0
# Parch                                  0
# Ticket                             14311
# Fare                                7.75
# Cabin                                NaN
# Embarked                               Q
# Name: 47, dtype: object
# PassengerId                     49
# Survived                         0
# Pclass                           3
# Name           Samaan, Mr. Youssef
# Sex                           male
# Age                            NaN
# SibSp                            2
# Parch                            0
# Ticket                        2662
# Fare                       21.6792
# Cabin                          NaN
# Embarked                         C
# Name: 48, dtype: object
# PassengerId                                               50
# Survived                                                   0
# Pclass                                                     3
# Name           Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# Sex                                                   female
# Age                                                     18.0
# SibSp                                                      1
# Parch                                                      0
# Ticket                                                349237
# Fare                                                    17.8
# Cabin                                                    NaN
# Embarked                                                   S
# Name: 49, dtype: object
# PassengerId                            51
# Survived                                0
# Pclass                                  3
# Name           Panula, Master. Juha Niilo
# Sex                                  male
# Age                                   7.0
# SibSp                                   4
# Parch                                   1
# Ticket                            3101295
# Fare                              39.6875
# Cabin                                 NaN
# Embarked                                S
# Name: 50, dtype: object
# PassengerId                              52
# Survived                                  0
# Pclass                                    3
# Name           Nosworthy, Mr. Richard Cater
# Sex                                    male
# Age                                    21.0
# SibSp                                     0
# Parch                                     0
# Ticket                           A/4. 39886
# Fare                                    7.8
# Cabin                                   NaN
# Embarked                                  S
# Name: 51, dtype: object
# PassengerId                                          53
# Survived                                              1
# Pclass                                                1
# Name           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# Sex                                              female
# Age                                                49.0
# SibSp                                                 1
# Parch                                                 0
# Ticket                                         PC 17572
# Fare                                            76.7292
# Cabin                                               D33
# Embarked                                              C
# Name: 52, dtype: object
# PassengerId                                                   54
# Survived                                                       1
# Pclass                                                         2
# Name           Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...
# Sex                                                       female
# Age                                                         29.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                      2926
# Fare                                                        26.0
# Cabin                                                        NaN
# Embarked                                                       S
# Name: 53, dtype: object
# PassengerId                                55
# Survived                                    0
# Pclass                                      1
# Name           Ostby, Mr. Engelhart Cornelius
# Sex                                      male
# Age                                      65.0
# SibSp                                       0
# Parch                                       1
# Ticket                                 113509
# Fare                                  61.9792
# Cabin                                     B30
# Embarked                                    C
# Name: 54, dtype: object
# PassengerId                   56
# Survived                       1
# Pclass                         1
# Name           Woolner, Mr. Hugh
# Sex                         male
# Age                          NaN
# SibSp                          0
# Parch                          0
# Ticket                     19947
# Fare                        35.5
# Cabin                        C52
# Embarked                       S
# Name: 55, dtype: object
# PassengerId                   57
# Survived                       1
# Pclass                         2
# Name           Rugg, Miss. Emily
# Sex                       female
# Age                         21.0
# SibSp                          0
# Parch                          0
# Ticket                C.A. 31026
# Fare                        10.5
# Cabin                        NaN
# Embarked                       S
# Name: 56, dtype: object
# PassengerId                     58
# Survived                         0
# Pclass                           3
# Name           Novel, Mr. Mansouer
# Sex                           male
# Age                           28.5
# SibSp                            0
# Parch                            0
# Ticket                        2697
# Fare                        7.2292
# Cabin                          NaN
# Embarked                         C
# Name: 57, dtype: object
# PassengerId                              59
# Survived                                  1
# Pclass                                    2
# Name           West, Miss. Constance Mirium
# Sex                                  female
# Age                                     5.0
# SibSp                                     1
# Parch                                     2
# Ticket                           C.A. 34651
# Fare                                  27.75
# Cabin                                   NaN
# Embarked                                  S
# Name: 58, dtype: object
# PassengerId                                    60
# Survived                                        0
# Pclass                                          3
# Name           Goodwin, Master. William Frederick
# Sex                                          male
# Age                                          11.0
# SibSp                                           5
# Parch                                           2
# Ticket                                    CA 2144
# Fare                                         46.9
# Cabin                                         NaN
# Embarked                                        S
# Name: 59, dtype: object
# PassengerId                       61
# Survived                           0
# Pclass                             3
# Name           Sirayanian, Mr. Orsen
# Sex                             male
# Age                             22.0
# SibSp                              0
# Parch                              0
# Ticket                          2669
# Fare                          7.2292
# Cabin                            NaN
# Embarked                           C
# Name: 60, dtype: object
# PassengerId                     62
# Survived                         1
# Pclass                           1
# Name           Icard, Miss. Amelie
# Sex                         female
# Age                           38.0
# SibSp                            0
# Parch                            0
# Ticket                      113572
# Fare                          80.0
# Cabin                          B28
# Embarked                       NaN
# Name: 61, dtype: object
# PassengerId                             63
# Survived                                 0
# Pclass                                   1
# Name           Harris, Mr. Henry Birkhardt
# Sex                                   male
# Age                                   45.0
# SibSp                                    1
# Parch                                    0
# Ticket                               36973
# Fare                                83.475
# Cabin                                  C83
# Embarked                                 S
# Name: 62, dtype: object
# PassengerId                       64
# Survived                           0
# Pclass                             3
# Name           Skoog, Master. Harald
# Sex                             male
# Age                              4.0
# SibSp                              3
# Parch                              2
# Ticket                        347088
# Fare                            27.9
# Cabin                            NaN
# Embarked                           S
# Name: 63, dtype: object
# PassengerId                       65
# Survived                           0
# Pclass                             1
# Name           Stewart, Mr. Albert A
# Sex                             male
# Age                              NaN
# SibSp                              0
# Parch                              0
# Ticket                      PC 17605
# Fare                         27.7208
# Cabin                            NaN
# Embarked                           C
# Name: 64, dtype: object
# PassengerId                          66
# Survived                              1
# Pclass                                3
# Name           Moubarek, Master. Gerios
# Sex                                male
# Age                                 NaN
# SibSp                                 1
# Parch                                 1
# Ticket                             2661
# Fare                            15.2458
# Cabin                               NaN
# Embarked                              C
# Name: 65, dtype: object
# PassengerId                              67
# Survived                                  1
# Pclass                                    2
# Name           Nye, Mrs. (Elizabeth Ramell)
# Sex                                  female
# Age                                    29.0
# SibSp                                     0
# Parch                                     0
# Ticket                           C.A. 29395
# Fare                                   10.5
# Cabin                                   F33
# Embarked                                  S
# Name: 66, dtype: object
# PassengerId                          68
# Survived                              0
# Pclass                                3
# Name           Crease, Mr. Ernest James
# Sex                                male
# Age                                19.0
# SibSp                                 0
# Parch                                 0
# Ticket                        S.P. 3464
# Fare                             8.1583
# Cabin                               NaN
# Embarked                              S
# Name: 67, dtype: object
# PassengerId                                 69
# Survived                                     1
# Pclass                                       3
# Name           Andersson, Miss. Erna Alexandra
# Sex                                     female
# Age                                       17.0
# SibSp                                        4
# Parch                                        2
# Ticket                                 3101281
# Fare                                     7.925
# Cabin                                      NaN
# Embarked                                     S
# Name: 68, dtype: object
# PassengerId                   70
# Survived                       0
# Pclass                         3
# Name           Kink, Mr. Vincenz
# Sex                         male
# Age                         26.0
# SibSp                          2
# Parch                          0
# Ticket                    315151
# Fare                      8.6625
# Cabin                        NaN
# Embarked                       S
# Name: 69, dtype: object
# PassengerId                            71
# Survived                                0
# Pclass                                  2
# Name           Jenkin, Mr. Stephen Curnow
# Sex                                  male
# Age                                  32.0
# SibSp                                   0
# Parch                                   0
# Ticket                         C.A. 33111
# Fare                                 10.5
# Cabin                                 NaN
# Embarked                                S
# Name: 70, dtype: object
# PassengerId                            72
# Survived                                0
# Pclass                                  3
# Name           Goodwin, Miss. Lillian Amy
# Sex                                female
# Age                                  16.0
# SibSp                                   5
# Parch                                   2
# Ticket                            CA 2144
# Fare                                 46.9
# Cabin                                 NaN
# Embarked                                S
# Name: 71, dtype: object
# PassengerId                      73
# Survived                          0
# Pclass                            2
# Name           Hood, Mr. Ambrose Jr
# Sex                            male
# Age                            21.0
# SibSp                             0
# Parch                             0
# Ticket                 S.O.C. 14879
# Fare                           73.5
# Cabin                           NaN
# Embarked                          S
# Name: 72, dtype: object
# PassengerId                             74
# Survived                                 0
# Pclass                                   3
# Name           Chronopoulos, Mr. Apostolos
# Sex                                   male
# Age                                   26.0
# SibSp                                    1
# Parch                                    0
# Ticket                                2680
# Fare                               14.4542
# Cabin                                  NaN
# Embarked                                 C
# Name: 73, dtype: object
# PassengerId               75
# Survived                   1
# Pclass                     3
# Name           Bing, Mr. Lee
# Sex                     male
# Age                     32.0
# SibSp                      0
# Parch                      0
# Ticket                  1601
# Fare                 56.4958
# Cabin                    NaN
# Embarked                   S
# Name: 74, dtype: object
# PassengerId                         76
# Survived                             0
# Pclass                               3
# Name           Moen, Mr. Sigurd Hansen
# Sex                               male
# Age                               25.0
# SibSp                                0
# Parch                                0
# Ticket                          348123
# Fare                              7.65
# Cabin                            F G73
# Embarked                             S
# Name: 75, dtype: object
# PassengerId                   77
# Survived                       0
# Pclass                         3
# Name           Staneff, Mr. Ivan
# Sex                         male
# Age                          NaN
# SibSp                          0
# Parch                          0
# Ticket                    349208
# Fare                      7.8958
# Cabin                        NaN
# Embarked                       S
# Name: 76, dtype: object
# PassengerId                          78
# Survived                              0
# Pclass                                3
# Name           Moutal, Mr. Rahamin Haim
# Sex                                male
# Age                                 NaN
# SibSp                                 0
# Parch                                 0
# Ticket                           374746
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 77, dtype: object
# PassengerId                               79
# Survived                                   1
# Pclass                                     2
# Name           Caldwell, Master. Alden Gates
# Sex                                     male
# Age                                     0.83
# SibSp                                      0
# Parch                                      2
# Ticket                                248738
# Fare                                    29.0
# Cabin                                    NaN
# Embarked                                   S
# Name: 78, dtype: object
# PassengerId                          80
# Survived                              1
# Pclass                                3
# Name           Dowdell, Miss. Elizabeth
# Sex                              female
# Age                                30.0
# SibSp                                 0
# Parch                                 0
# Ticket                           364516
# Fare                             12.475
# Cabin                               NaN
# Embarked                              S
# Name: 79, dtype: object
# PassengerId                      81
# Survived                          0
# Pclass                            3
# Name           Waelens, Mr. Achille
# Sex                            male
# Age                            22.0
# SibSp                             0
# Parch                             0
# Ticket                       345767
# Fare                            9.0
# Cabin                           NaN
# Embarked                          S
# Name: 80, dtype: object
# PassengerId                             82
# Survived                                 1
# Pclass                                   3
# Name           Sheerlinck, Mr. Jan Baptist
# Sex                                   male
# Age                                   29.0
# SibSp                                    0
# Parch                                    0
# Ticket                              345779
# Fare                                   9.5
# Cabin                                  NaN
# Embarked                                 S
# Name: 81, dtype: object
# PassengerId                                83
# Survived                                    1
# Pclass                                      3
# Name           McDermott, Miss. Brigdet Delia
# Sex                                    female
# Age                                       NaN
# SibSp                                       0
# Parch                                       0
# Ticket                                 330932
# Fare                                   7.7875
# Cabin                                     NaN
# Embarked                                    Q
# Name: 82, dtype: object
# PassengerId                         84
# Survived                             0
# Pclass                               1
# Name           Carrau, Mr. Francisco M
# Sex                               male
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          113059
# Fare                              47.1
# Cabin                              NaN
# Embarked                             S
# Name: 83, dtype: object
# PassengerId                     85
# Survived                         1
# Pclass                           2
# Name           Ilett, Miss. Bertha
# Sex                         female
# Age                           17.0
# SibSp                            0
# Parch                            0
# Ticket                  SO/C 14885
# Fare                          10.5
# Cabin                          NaN
# Embarked                         S
# Name: 84, dtype: object
# PassengerId                                                   86
# Survived                                                       1
# Pclass                                                         3
# Name           Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...
# Sex                                                       female
# Age                                                         33.0
# SibSp                                                          3
# Parch                                                          0
# Ticket                                                   3101278
# Fare                                                       15.85
# Cabin                                                        NaN
# Embarked                                                       S
# Name: 85, dtype: object
# PassengerId                        87
# Survived                            0
# Pclass                              3
# Name           Ford, Mr. William Neal
# Sex                              male
# Age                              16.0
# SibSp                               1
# Parch                               3
# Ticket                     W./C. 6608
# Fare                           34.375
# Cabin                             NaN
# Embarked                            S
# Name: 86, dtype: object
# PassengerId                               88
# Survived                                   0
# Pclass                                     3
# Name           Slocovski, Mr. Selman Francis
# Sex                                     male
# Age                                      NaN
# ...
# Fare                                                     25.9292
# Cabin                                                        D17
# Embarked                                                       S
# Name: 862, dtype: object
# PassengerId                                  864
# Survived                                       0
# Pclass                                         3
# Name           Sage, Miss. Dorothy Edith "Dolly"
# Sex                                       female
# Age                                          NaN
# SibSp                                          8
# Parch                                          2
# Ticket                                  CA. 2343
# Fare                                       69.55
# Cabin                                        NaN
# Embarked                                       S
# Name: 863, dtype: object
# PassengerId                       865
# Survived                            0
# Pclass                              2
# Name           Gill, Mr. John William
# Sex                              male
# Age                              24.0
# SibSp                               0
# Parch                               0
# Ticket                         233866
# Fare                             13.0
# Cabin                             NaN
# Embarked                            S
# Name: 864, dtype: object
# PassengerId                         866
# Survived                              1
# Pclass                                2
# Name           Bystrom, Mrs. (Karolina)
# Sex                              female
# Age                                42.0
# SibSp                                 0
# Parch                                 0
# Ticket                           236852
# Fare                               13.0
# Cabin                               NaN
# Embarked                              S
# Name: 865, dtype: object
# PassengerId                             867
# Survived                                  1
# Pclass                                    2
# Name           Duran y More, Miss. Asuncion
# Sex                                  female
# Age                                    27.0
# SibSp                                     1
# Parch                                     0
# Ticket                        SC/PARIS 2149
# Fare                                13.8583
# Cabin                                   NaN
# Embarked                                  C
# Name: 866, dtype: object
# PassengerId                                     868
# Survived                                          0
# Pclass                                            1
# Name           Roebling, Mr. Washington Augustus II
# Sex                                            male
# Age                                            31.0
# SibSp                                             0
# Parch                                             0
# Ticket                                     PC 17590
# Fare                                        50.4958
# Cabin                                           A24
# Embarked                                          S
# Name: 867, dtype: object
# PassengerId                            869
# Survived                                 0
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                    NaN
# SibSp                                    0
# Parch                                    0
# Ticket                              345777
# Fare                                   9.5
# Cabin                                  NaN
# Embarked                                 S
# Name: 868, dtype: object
# PassengerId                                870
# Survived                                     1
# Pclass                                       3
# Name           Johnson, Master. Harold Theodor
# Sex                                       male
# Age                                        4.0
# SibSp                                        1
# Parch                                        1
# Ticket                                  347742
# Fare                                   11.1333
# Cabin                                      NaN
# Embarked                                     S
# Name: 869, dtype: object
# PassengerId                  871
# Survived                       0
# Pclass                         3
# Name           Balkic, Mr. Cerin
# Sex                         male
# Age                         26.0
# SibSp                          0
# Parch                          0
# Ticket                    349248
# Fare                      7.8958
# Cabin                        NaN
# Embarked                       S
# Name: 870, dtype: object
# PassengerId                                                 872
# Survived                                                      1
# Pclass                                                        1
# Name           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# Sex                                                      female
# Age                                                        47.0
# SibSp                                                         1
# Parch                                                         1
# Ticket                                                    11751
# Fare                                                    52.5542
# Cabin                                                       D35
# Embarked                                                      S
# Name: 871, dtype: object
# PassengerId                         873
# Survived                              0
# Pclass                                1
# Name           Carlsson, Mr. Frans Olof
# Sex                                male
# Age                                33.0
# SibSp                                 0
# Parch                                 0
# Ticket                              695
# Fare                                5.0
# Cabin                       B51 B53 B55
# Embarked                              S
# Name: 872, dtype: object
# PassengerId                            874
# Survived                                 0
# Pclass                                   3
# Name           Vander Cruyssen, Mr. Victor
# Sex                                   male
# Age                                   47.0
# SibSp                                    0
# Parch                                    0
# Ticket                              345765
# Fare                                   9.0
# Cabin                                  NaN
# Embarked                                 S
# Name: 873, dtype: object
# PassengerId                                      875
# Survived                                           1
# Pclass                                             2
# Name           Abelson, Mrs. Samuel (Hannah Wizosky)
# Sex                                           female
# Age                                             28.0
# SibSp                                              1
# Parch                                              0
# Ticket                                     P/PP 3381
# Fare                                            24.0
# Cabin                                            NaN
# Embarked                                           C
# Name: 874, dtype: object
# PassengerId                                 876
# Survived                                      1
# Pclass                                        3
# Name           Najib, Miss. Adele Kiamie "Jane"
# Sex                                      female
# Age                                        15.0
# SibSp                                         0
# Parch                                         0
# Ticket                                     2667
# Fare                                      7.225
# Cabin                                       NaN
# Embarked                                      C
# Name: 875, dtype: object
# PassengerId                              877
# Survived                                   0
# Pclass                                     3
# Name           Gustafsson, Mr. Alfred Ossian
# Sex                                     male
# Age                                     20.0
# SibSp                                      0
# Parch                                      0
# Ticket                                  7534
# Fare                                  9.8458
# Cabin                                    NaN
# Embarked                                   S
# Name: 876, dtype: object
# PassengerId                     878
# Survived                          0
# Pclass                            3
# Name           Petroff, Mr. Nedelio
# Sex                            male
# Age                            19.0
# SibSp                             0
# Parch                             0
# Ticket                       349212
# Fare                         7.8958
# Cabin                           NaN
# Embarked                          S
# Name: 877, dtype: object
# PassengerId                   879
# Survived                        0
# Pclass                          3
# Name           Laleff, Mr. Kristo
# Sex                          male
# Age                           NaN
# SibSp                           0
# Parch                           0
# Ticket                     349217
# Fare                       7.8958
# Cabin                         NaN
# Embarked                        S
# Name: 878, dtype: object
# PassengerId                                              880
# Survived                                                   1
# Pclass                                                     1
# Name           Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# Sex                                                   female
# Age                                                     56.0
# SibSp                                                      0
# Parch                                                      1
# Ticket                                                 11767
# Fare                                                 83.1583
# Cabin                                                    C50
# Embarked                                                   C
# Name: 879, dtype: object
# PassengerId                                             881
# Survived                                                  1
# Pclass                                                    2
# Name           Shelley, Mrs. William (Imanita Parrish Hall)
# Sex                                                  female
# Age                                                    25.0
# SibSp                                                     0
# Parch                                                     1
# Ticket                                               230433
# Fare                                                   26.0
# Cabin                                                   NaN
# Embarked                                                  S
# Name: 880, dtype: object
# PassengerId                   882
# Survived                        0
# Pclass                          3
# Name           Markun, Mr. Johann
# Sex                          male
# Age                          33.0
# SibSp                           0
# Parch                           0
# Ticket                     349257
# Fare                       7.8958
# Cabin                         NaN
# Embarked                        S
# Name: 881, dtype: object
# PassengerId                             883
# Survived                                  0
# Pclass                                    3
# Name           Dahlberg, Miss. Gerda Ulrika
# Sex                                  female
# Age                                    22.0
# SibSp                                     0
# Parch                                     0
# Ticket                                 7552
# Fare                                10.5167
# Cabin                                   NaN
# Embarked                                  S
# Name: 882, dtype: object
# PassengerId                              884
# Survived                                   0
# Pclass                                     2
# Name           Banfield, Mr. Frederick James
# Sex                                     male
# Age                                     28.0
# SibSp                                      0
# Parch                                      0
# Ticket                      C.A./SOTON 34068
# Fare                                    10.5
# Cabin                                    NaN
# Embarked                                   S
# Name: 883, dtype: object
# PassengerId                       885
# Survived                            0
# Pclass                              3
# Name           Sutehall, Mr. Henry Jr
# Sex                              male
# Age                              25.0
# SibSp                               0
# Parch                               0
# Ticket                SOTON/OQ 392076
# Fare                             7.05
# Cabin                             NaN
# Embarked                            S
# Name: 884, dtype: object
# PassengerId                                     886
# Survived                                          0
# Pclass                                            3
# Name           Rice, Mrs. William (Margaret Norton)
# Sex                                          female
# Age                                            39.0
# SibSp                                             0
# Parch                                             5
# Ticket                                       382652
# Fare                                         29.125
# Cabin                                           NaN
# Embarked                                          Q
# Name: 885, dtype: object
# PassengerId                      887
# Survived                           0
# Pclass                             2
# Name           Montvila, Rev. Juozas
# Sex                             male
# Age                             27.0
# SibSp                              0
# Parch                              0
# Ticket                        211536
# Fare                            13.0
# Cabin                            NaN
# Embarked                           S
# Name: 886, dtype: object
# PassengerId                             888
# Survived                                  1
# Pclass                                    1
# Name           Graham, Miss. Margaret Edith
# Sex                                  female
# Age                                    19.0
# SibSp                                     0
# Parch                                     0
# Ticket                               112053
# Fare                                   30.0
# Cabin                                   B42
# Embarked                                  S
# Name: 887, dtype: object
# PassengerId                                         889
# Survived                                              0
# Pclass                                                3
# Name           Johnston, Miss. Catherine Helen "Carrie"
# Sex                                              female
# Age                                                 NaN
# SibSp                                                 1
# Parch                                                 2
# Ticket                                       W./C. 6607
# Fare                                              23.45
# Cabin                                               NaN
# Embarked                                              S
# Name: 888, dtype: object
# PassengerId                      890
# Survived                           1
# Pclass                             1
# Name           Behr, Mr. Karl Howell
# Sex                             male
# Age                             26.0
# SibSp                              0
# Parch                              0
# Ticket                        111369
# Fare                            30.0
# Cabin                           C148
# Embarked                           C
# Name: 889, dtype: object
# PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                           32.0
# SibSp                            0
# Parch                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Name: 890, dtype: object
